# %% [markdown]
# # 의사결정나무 분류 decision tree classification
# * **1, 2학기 전체**로 y = 각 시간별 주문 혼잡도 확인

# %% [markdown]
# ### 라이브러리 임포트

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
import graphviz
from graphviz import Source
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
import pickle

# %% [markdown]
# ### data 불러오기

# %%
df = pd.read_excel("../final_for_regression.xlsx")
df.head()
# Out:
#           일자  semester  season  event  day of the week  time  기온(°C)  풍속(m/s)  \
# 0 2022-03-02         1       0      0                2     8    -2.9      0.6
# 1 2022-03-02         1       0      0                2     9     0.4      1.2
# 2 2022-03-02         1       0      0                2    10     3.6      0.3
# 3 2022-03-02         1       0      0                2    11     5.2      1.3
# 4 2022-03-02         1       0      0                2    12     6.8      1.2
#
#    강수량(mm)  습도(%)  합계
# 0      0.0     78  15
# 1      0.0     59  12
# 2      0.0     47  18
# 3      0.0     42  39
# 4      0.0     27  34

# %%
df = df.rename(columns = {'day of the week' : '요일', 'season' : '계절', 'semester' : '학기', 'time': 'hour'})   # 보기 편하게 열 이름 rename
df
# Out:
#              일자  학기  계절  event  요일  hour  기온(°C)  풍속(m/s)  강수량(mm)  습도(%)  합계
# 0    2022-03-02   1   0      0   2     8    -2.9      0.6      0.0     78  15
# 1    2022-03-02   1   0      0   2     9     0.4      1.2      0.0     59  12
# 2    2022-03-02   1   0      0   2    10     3.6      0.3      0.0     47  18
# 3    2022-03-02   1   0      0   2    11     5.2      1.3      0.0     42  39
# 4    2022-03-02   1   0      0   2    12     6.8      1.2      0.0     27  34
# ...         ...  ..  ..    ...  ..   ...     ...      ...      ...    ...  ..
# 1471 2022-12-21   2  11      2   2    13     0.3      0.8      0.0     89  40
# 1472 2022-12-21   2  11      2   2    14     0.6      1.0      0.0     88  39
# 1473 2022-12-21   2  11      2   2    15     2.0      0.1      0.0     83  22
# 1474 2022-12-21   2  11      2   2    16     0.7      0.5      0.0     89  27
# 1475 2022-12-21   2  11      2   2    17    -0.6      0.1      0.0     96   3
#
# [1476 rows x 11 columns]

# %% [markdown]
# ## Decision Tree 모델에 맞게 데이터 전처리
#
# #### Categorical 데이터들을 Decision Tree 모델이 이해할 수 있는 **One-Hot Encoding**을 통해 binary data로 변환

# %%
# one-hot encoding을 위해, 숫자형으로 바꿨던 것을 다시 범주형으로 바꿔줌
# (기존에 정의한 함수 mapping 사용)

from prep_function.onehotmap import *

df = map_season(df, '계절')
df = map_event(df, 'event')
df = map_day(df, '요일')
df = map_hour(df, 'hour')

df.head()  # 바뀐 df 확인
# Out:
#           일자  학기 계절 event   요일 hour  기온(°C)  풍속(m/s)  강수량(mm)  습도(%)  합계
# 0 2022-03-02   1  봄    평소  수요일   8시    -2.9      0.6      0.0     78  15
# 1 2022-03-02   1  봄    평소  수요일   9시     0.4      1.2      0.0     59  12
# 2 2022-03-02   1  봄    평소  수요일  10시     3.6      0.3      0.0     47  18
# 3 2022-03-02   1  봄    평소  수요일  11시     5.2      1.3      0.0     42  39
# 4 2022-03-02   1  봄    평소  수요일  12시     6.8      1.2      0.0     27  34

# %%
# '계절', 'event', '요일'에 대해 one-hot encoding 수행
data_encoded = pd.get_dummies(df, columns=['계절', 'event', '요일', 'hour'])

data_encoded   # one-hot encoding 잘됐는지 확인
# Out:
#              일자  학기  기온(°C)  풍속(m/s)  강수량(mm)  습도(%)  합계  계절_가을  계절_겨울   계절_봄  \
# 0    2022-03-02   1    -2.9      0.6      0.0     78  15  False  False   True
# 1    2022-03-02   1     0.4      1.2      0.0     59  12  False  False   True
# 2    2022-03-02   1     3.6      0.3      0.0     47  18  False  False   True
# 3    2022-03-02   1     5.2      1.3      0.0     42  39  False  False   True
# 4    2022-03-02   1     6.8      1.2      0.0     27  34  False  False   True
# ...         ...  ..     ...      ...      ...    ...  ..    ...    ...    ...
# 1471 2022-12-21   2     0.3      0.8      0.0     89  40  False   True  False
# 1472 2022-12-21   2     0.6      1.0      0.0     88  39  False   True  False
# 1473 2022-12-21   2     2.0      0.1      0.0     83  22  False   True  False
# 1474 2022-12-21   2     0.7      0.5      0.0     89  27  False   True  False
# 1475 2022-12-21   2    -0.6      0.1      0.0     96   3  False   True  False
#
#       ...  hour_10시  hour_11시  hour_12시  hour_13시  hour_14시  hour_15시  \
# 0     ...     False     False     False     False     False     False
# 1     ...     False     False     False     False     False     False
# 2     ...      True     False     False     False     False     False
# 3     ...     False      True     False     False     False     False
# 4     ...     False     False      True     False     False     False
# ...   ...       ...       ...       ...       ...       ...       ...
# 1471  ...     False     False     False      True     False     False
# 1472  ...     False     False     False     False      True     False
# 1473  ...     False     False     False     False     False      True
# 1474  ...     False     False     False     False     False     False
# 1475  ...     False     False     False     False     False     False
#
#       hour_16시  hour_17시  hour_8시  hour_9시
# 0        False     False     True    False
# 1        False     False    False     True
# 2        False     False    False    False
# 3        False     False    False    False
# 4        False     False    False    False
# ...        ...       ...      ...      ...
# 1471     False     False    False    False
# 1472     False     False    False    False
# 1473     False     False    False    False
# 1474      True     False    False    False
# 1475     False      True    False    False
#
# [1476 rows x 30 columns]

# %% [markdown]
# #### 일자 없애기
# * decision tree에선 datetime 데이터 타입을 받을 수 없기 때문에 진행해줘야 함
# * 슬라이싱 진행

# %%
data = data_encoded.iloc[:, 1:]
data
# Out:
#       학기  기온(°C)  풍속(m/s)  강수량(mm)  습도(%)  합계  계절_가을  계절_겨울   계절_봄  계절_여름  \
# 0      1    -2.9      0.6      0.0     78  15  False  False   True  False
# 1      1     0.4      1.2      0.0     59  12  False  False   True  False
# 2      1     3.6      0.3      0.0     47  18  False  False   True  False
# 3      1     5.2      1.3      0.0     42  39  False  False   True  False
# 4      1     6.8      1.2      0.0     27  34  False  False   True  False
# ...   ..     ...      ...      ...    ...  ..    ...    ...    ...    ...
# 1471   2     0.3      0.8      0.0     89  40  False   True  False  False
# 1472   2     0.6      1.0      0.0     88  39  False   True  False  False
# 1473   2     2.0      0.1      0.0     83  22  False   True  False  False
# 1474   2     0.7      0.5      0.0     89  27  False   True  False  False
# 1475   2    -0.6      0.1      0.0     96   3  False   True  False  False
#
#       ...  hour_10시  hour_11시  hour_12시  hour_13시  hour_14시  hour_15시  \
# 0     ...     False     False     False     False     False     False
# 1     ...     False     False     False     False     False     False
# 2     ...      True     False     False     False     False     False
# 3     ...     False      True     False     False     False     False
# 4     ...     False     False      True     False     False     False
# ...   ...       ...       ...       ...       ...       ...       ...
# 1471  ...     False     False     False      True     False     False
# 1472  ...     False     False     False     False      True     False
# 1473  ...     False     False     False     False     False      True
# 1474  ...     False     False     False     False     False     False
# 1475  ...     False     False     False     False     False     False
#
#       hour_16시  hour_17시  hour_8시  hour_9시
# 0        False     False     True    False
# 1        False     False    False     True
# 2        False     False    False    False
# 3        False     False    False    False
# 4        False     False    False    False
# ...        ...       ...      ...      ...
# 1471     False     False    False    False
# 1472     False     False    False    False
# 1473     False     False    False    False
# 1474      True     False    False    False
# 1475     False      True    False    False
#
# [1476 rows x 29 columns]

# %% [markdown]
# #### 데이터프레임 보기 좋게 정렬

# %%
# one-hot encoding을 진행해줬던 열들의 이름이 '(one-hot encode 당한 열의 이름)_(해당 열의 속성값)'으로 구성되어있음
# 가독성을 위해, '(해당 열의 속성값)'만 남겨두고 언더바부터 앞의 문자까지 삭제해주는 전처리 진행

# 미리 지정해둔 함수를 통해 전처리
from prep_function.dfrename import *

data = rename_columns(data)
data.head()
# Out:
#    학기  기온(°C)  풍속(m/s)  강수량(mm)  습도(%)  합계     가을     겨울     봄     여름  ...  \
# 0   1    -2.9      0.6      0.0     78  15  False  False  True  False  ...
# 1   1     0.4      1.2      0.0     59  12  False  False  True  False  ...
# 2   1     3.6      0.3      0.0     47  18  False  False  True  False  ...
# 3   1     5.2      1.3      0.0     42  39  False  False  True  False  ...
# 4   1     6.8      1.2      0.0     27  34  False  False  True  False  ...
#
#      10시    11시    12시    13시    14시    15시    16시    17시     8시     9시
# 0  False  False  False  False  False  False  False  False   True  False
# 1  False  False  False  False  False  False  False  False  False   True
# 2   True  False  False  False  False  False  False  False  False  False
# 3  False   True  False  False  False  False  False  False  False  False
# 4  False  False   True  False  False  False  False  False  False  False
#
# [5 rows x 29 columns]

# %%
# 새로운 열 (교시) 추가

data['1-2교시'] = ((data['8시'] | data['9시'] | data['10시'] | data['11시'])).astype(int)
data['3-4교시'] = ((data['12시'] | data['13시'] | data['14시'])).astype(int)
data['5-6교시'] = ((data['15시'] | data['16시'] | data['17시'])).astype(int)

# %%
data.columns    # 해당 데이터프레임의 columns가 뭐가 있는지 확인하기 위함
# Out:
# Index(['학기', '기온(°C)', '풍속(m/s)', '강수량(mm)', '습도(%)', '합계', '가을', '겨울', '봄',
#        '여름', '보강주', '시험', '축제', '평소', '금요일', '목요일', '수요일', '월요일', '화요일', '10시',
#        '11시', '12시', '13시', '14시', '15시', '16시', '17시', '8시', '9시', '1-2교시',
#        '3-4교시', '5-6교시'],
#       dtype='object')

# %%
# 보기 쉬운 열 정렬로 직접 정렬해줌

data = data[['학기', '8시', '9시', '10시', '11시', '12시', 
             '13시', '14시', '15시', '16시', '17시', 
             '1-2교시', '3-4교시', '5-6교시',
             '봄', '여름', '가을', '겨울', 
             '보강주', '시험', '축제', '평소', 
             '월요일', '화요일', '수요일', '목요일', '금요일', 
             '기온(°C)', '풍속(m/s)', '강수량(mm)', '습도(%)', '합계']]

data.head()  # 정렬 모습 확인
# Out:
#    학기     8시     9시    10시    11시    12시    13시    14시    15시    16시  ...  \
# 0   1   True  False  False  False  False  False  False  False  False  ...
# 1   1  False   True  False  False  False  False  False  False  False  ...
# 2   1  False  False   True  False  False  False  False  False  False  ...
# 3   1  False  False  False   True  False  False  False  False  False  ...
# 4   1  False  False  False  False   True  False  False  False  False  ...
#
#      월요일    화요일   수요일    목요일    금요일  기온(°C)  풍속(m/s)  강수량(mm)  습도(%)  합계
# 0  False  False  True  False  False    -2.9      0.6      0.0     78  15
# 1  False  False  True  False  False     0.4      1.2      0.0     59  12
# 2  False  False  True  False  False     3.6      0.3      0.0     47  18
# 3  False  False  True  False  False     5.2      1.3      0.0     42  39
# 4  False  False  True  False  False     6.8      1.2      0.0     27  34
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Decision Tree Classfication을 위해 혼잡도 계산
# * 합계 열을 기준으로, 주문 혼잡도를 계산
#   * 혼잡: 55 이상
#   * 보통: 55 미만 25 이상
#   * 여유: 25 미만

# %%
# 혼잡도 기준 리스트 만들기
conditions = [
        (data['합계'] >= 55),
        (data['합계'] < 55) & (df['합계'] >= 25),
        (data['합계'] < 25)
    ]

choices = ['혼잡', '보통', '여유']

# %%
# 혼잡도 column 만들기
# numpy.select를 사용하여 새로운 혼잡도 열을 생성
data['혼잡도'] = np.select(conditions, choices, default='Unknown')

dt_data = data
dt_data.drop("합계", axis=1, inplace=True)

# 데이터 확인
dt_data.head()
# Out:
# C:\Users\sohtk\AppData\Local\Temp\ipykernel_31856\816451740.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['혼잡도'] = np.select(conditions, choices, default='Unknown')
#    학기     8시     9시    10시    11시    12시    13시    14시    15시    16시  ...  \
# 0   1   True  False  False  False  False  False  False  False  False  ...
# 1   1  False   True  False  False  False  False  False  False  False  ...
# 2   1  False  False   True  False  False  False  False  False  False  ...
# 3   1  False  False  False   True  False  False  False  False  False  ...
# 4   1  False  False  False  False   True  False  False  False  False  ...
#
#      월요일    화요일   수요일    목요일    금요일  기온(°C)  풍속(m/s)  강수량(mm)  습도(%)  혼잡도
# 0  False  False  True  False  False    -2.9      0.6      0.0     78   여유
# 1  False  False  True  False  False     0.4      1.2      0.0     59   여유
# 2  False  False  True  False  False     3.6      0.3      0.0     47   여유
# 3  False  False  True  False  False     5.2      1.3      0.0     42   보통
# 4  False  False  True  False  False     6.8      1.2      0.0     27   보통
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Decision Tree Classification 진행

# %% [markdown]
# #### X와 y 지정

# %%
num_cols = list(dt_data.columns)
num_cols.remove('혼잡도')   # 데이터프레임 전체의 columns를 리스트로 받아왔었기 때문에, y로 들어갈 '혼잡도'를 제거

X = dt_data[num_cols]
y = dt_data["혼잡도"]

# %%
y_dic = { '혼잡' : 0,
          '보통' : 1,
          '여유' : 2 }

y = y.map(y_dic)

# %% [markdown]
# ### Decision Tree Experiment
# 1. **임의로 랜덤**하게 test셋과 train셋을 나눔

# %%
train_input, test_input, train_target, test_target = train_test_split(X, y, random_state=42)
# random_state: 호출할 때마다 동일한 train/test dataset을 생성하기 위해 주어지는 parameter

# %% [markdown]
# * 최적의 parameter를 찾기 위해 **Grid Search** 사용
#   * 교차검증과 최적의 하이퍼파라미터 튜닝을 한번에 할 수 있음

# %%
# decision tree 모델 설정
dtree = DecisionTreeClassifier()

### parameter들을 dictionary 형태로 설정
parameters = {'max_depth':[3, 4, 5, 6], 'min_samples_split':[2, 3, 4]}

# param_grid의 하이퍼 파라미터들을 3개의 train, test set fold 로 나누어서 테스트 수행 설정
### refit=True 가 default
  # True이면 가장 좋은 파라미터 설정으로 retrain 시킴!
grid_dtree = GridSearchCV(dtree, param_grid=parameters, cv=3, refit=True)

# Train 데이터로 param_grid의 하이퍼 파라미터들을 순차적으로 학습/평가
grid_dtree.fit(train_input, train_target)

# GridSearchCV 결과 추출하여 DataFrame으로 변환
scores_df = pd.DataFrame(grid_dtree.cv_results_)
scores_df[['params', 'mean_test_score', 'rank_test_score', \
           'split0_test_score', 'split1_test_score', 'split2_test_score']]
# Out:
#                                       params  mean_test_score  \
# 0   {'max_depth': 3, 'min_samples_split': 2}         0.647696
# 1   {'max_depth': 3, 'min_samples_split': 3}         0.647696
# 2   {'max_depth': 3, 'min_samples_split': 4}         0.647696
# 3   {'max_depth': 4, 'min_samples_split': 2}         0.691057
# 4   {'max_depth': 4, 'min_samples_split': 3}         0.691057
# 5   {'max_depth': 4, 'min_samples_split': 4}         0.691057
# 6   {'max_depth': 5, 'min_samples_split': 2}         0.704607
# 7   {'max_depth': 5, 'min_samples_split': 3}         0.702800
# 8   {'max_depth': 5, 'min_samples_split': 4}         0.697380
# 9   {'max_depth': 6, 'min_samples_split': 2}         0.718157
# 10  {'max_depth': 6, 'min_samples_split': 3}         0.719061
# 11  {'max_depth': 6, 'min_samples_split': 4}         0.717254
#
#     rank_test_score  split0_test_score  split1_test_score  split2_test_score
# 0                10           0.644986           0.661247           0.636856
# 1                10           0.644986           0.661247           0.636856
# 2                10           0.644986           0.661247           0.636856
# 3                 7           0.707317           0.691057           0.674797
# 4                 7           0.707317           0.691057           0.674797
# 5                 7           0.707317           0.691057           0.674797
# 6                 4           0.701897           0.704607           0.707317
# 7                 5           0.701897           0.699187           0.707317
# 8                 6           0.691057           0.693767           0.707317
# 9                 2           0.685637           0.737127           0.731707
# 10                1           0.688347           0.737127           0.731707
# 11                3           0.685637           0.734417           0.731707

# %% [markdown]
# * 최적의 parameter
# * 그걸로 돌린 최고 정확도를 출력
#
# * 이후, 최적의 parameter을 가지고 있는 best_estimator_를 사용해서 테스트 데이터 셋의 accuracy 확인

# %%
print('GridSearchCV 최적 파라미터:', grid_dtree.best_params_)
print('GridSearchCV 최고 정확도: {0:.4f}'.format(grid_dtree.best_score_))

# GridSearchCV의 refit으로 이미 학습이 된 estimator 반환
estimator = grid_dtree.best_estimator_

# GridSearchCV의 best_estimator_는 이미 최적 하이퍼 파라미터로 학습이 됨
pred = estimator.predict(test_input)
print('test data set accuracy: {0:.4f}'.format(accuracy_score(test_target, pred)))
# Out:
# GridSearchCV 최적 파라미터: {'max_depth': 6, 'min_samples_split': 3}
# GridSearchCV 최고 정확도: 0.7191
# test data set accuracy: 0.7100

# %% [markdown]
# ### Decision Tree Classification 시각화

# %%
# 시각화를 위해 미리 pip install 해야함
# !pip install graphviz

# %%
# export_graphviz를 사용하여 .dot 파일 데이터 생성
dot_data = export_graphviz(
    estimator, 
    out_file=None,  # None으로 설정하여 문자열로 반환
    feature_names=X.columns, 
    class_names=['혼잡', '보통', '여유'],
    impurity=False, 
    filled=True,
    rounded=True,
    special_characters=True,
    fontname='Malgun Gothic'
)

# Source 객체를 생성하여 .dot 데이터를 PNG로 렌더링
source = Source(dot_data, format='png')
source.render('tree_visualization')
# Out:
# 'tree_visualization.png'

# %%
export_graphviz(estimator, out_file="tree_cv.dot", class_names=['혼잡', '보통', '여유'], feature_names = X.columns, impurity = False, filled = True)
with open("tree_cv.dot", encoding="UTF8") as f:
    dot_graph = f.read()
    display(graphviz.Source(dot_graph))

# %% [markdown]
# #### 각 특성들의 **중요도 수치** 확인
# * 해당 모델의 중요도를 dataframe에 넣음

# %%
fe = estimator.feature_importances_  # 특성 중요도 수치
fe_im_df = pd.DataFrame(fe, index=X.columns)
fe_im_df
# Out:
#                 0
# 학기       0.038492
# 8시       0.000000
# 9시       0.000000
# 10시      0.007712
# 11시      0.150681
# 12시      0.006963
# 13시      0.000404
# 14시      0.000000
# 15시      0.025116
# 16시      0.000000
# 17시      0.000000
# 1-2교시    0.002379
# 3-4교시    0.285351
# 5-6교시    0.052739
# 봄        0.052327
# 여름       0.008323
# 가을       0.019661
# 겨울       0.003802
# 보강주      0.022355
# 시험       0.007334
# 축제       0.013481
# 평소       0.008411
# 월요일      0.008555
# 화요일      0.000000
# 수요일      0.000000
# 목요일      0.001697
# 금요일      0.155438
# 기온(°C)   0.074288
# 풍속(m/s)  0.034770
# 강수량(mm)  0.000000
# 습도(%)    0.019721

# %%
fe_im_df.info()

# 해당 열의 이름을 importance로 지정
fe_im_df.columns = ['importance']
fe_im_df.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31 entries, 학기 to 습도(%)
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       31 non-null     float64
# dtypes: float64(1)
# memory usage: 1.5+ KB
#     importance
# 학기    0.038492
# 8시    0.000000

# %%
### 중요도를 시각화

fe_df = fe_im_df[fe_im_df['importance'] > 0]

### figure size
# plt.figure(figsize=(5, 8))

### bar plot : matplotlib.pyplot 모듈의 barh() 함수를 사용해서 수평 막대 그래프를 그림
plt.barh(fe_df.index.to_list(), fe_df['importance'])
plt.title('1, 2학기 : "feature - importance" Graph')
plt.xlabel('importance')
plt.ylabel('features')

plt.rcParams['font.family'] = 'Malgun Gothic'     # 한국어 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False        # 마이너스 깨짐 방지

plt.show()

# %% [markdown]
# ### 학습시킨 모델의 지표를 확인

# %%
# Confusion Matrix
conf_matrix = confusion_matrix(test_target, pred)
print("Confusion Matrix:")
print(conf_matrix)

# Accuracy
accuracy = accuracy_score(test_target, pred)
print("\nAccuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Confusion Matrix:
# [[81 15  2]
#  [19 84 35]
#  [ 3 33 97]]
#
# Accuracy: 71.00%

# %%
# y로 나타난 혼잡도의 고유값이 몇 번 나타나는지 세기
value_counts = dt_data['혼잡도'].value_counts()
print(f"혼잡도 각 속성에 대한 행 개수:\n{value_counts}")
# Out:
# 혼잡도 각 속성에 대한 행 개수:
# 혼잡도
# 보통    556
# 여유    535
# 혼잡    385
# Name: count, dtype: int64

# %%
# Precision, Recall, F1 Score
precision = precision_score(test_target, pred, average='macro') 
recall = recall_score(test_target, pred, average='macro')
f1 = f1_score(test_target, pred, average='macro')
# average: 사용하여 여러 클래스에 대한 평균을 어떻게 취할지 정의
   # average='macro': 클래스 간 샘플 불균형이 있더라도 모든 클래스를 같은 가중치로 취급하지만,
   # 각 클래스를 동일하게 중요하게 여기기 때문에 macro로 선정


print("\nPrecision: {:.2f}".format(precision))
print("Recall: {:.2f}".format(recall))
print("F1 Score: {:.2f}".format(f1))
# Out:
# Precision: 0.72
# Recall: 0.72
# F1 Score: 0.72

# %% [markdown]
# ### 학습시킨 모델 저장

# %%
# 모델 저장
with open('decision_tree_model_full.pkl', 'wb') as file:
    pickle.dump(estimator, file)

# # 모델 불러오기
# with open('decision_tree_model_full.pkl', 'rb') as file:
#     loaded_model = pickle.load(file)
